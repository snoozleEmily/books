# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
#print(df.columns)

#print(df[['Name', 'Sp. Def']][390:400])

# %%
#print(df.iloc[613])

# %%
#for index, row in df.iterrows():
 #   print(index, row)

# %%
#f.loc[(df['Type 1'] == 'Water') & (df['HP'] >= 84) & (df['Legendary'] == True)]

# %%
#df.sort_values(['Name', 'Attack'], ascending=[1,0])

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#df.head(5)

# %%
#df = df.drop(columns=['Total'])
#df.head(5)

# %%
#df['Total'] = df.iloc[:, 4:10].sum(axis=1)
#df.head(5)

# %%
#cols = list(df.columns.values)
#df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
#df.head(5)

# %%
#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

#df.to_csv('modified.txt', index=False, sep='\t')

# %%
sample = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

sample.tail()

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
import re

df.loc[df['Type 1'].str.contains('fiRe|grAss', flags=re.IGNORECASE, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[(df['Name'].str.contains('^pi[a-z]*', flags=re.IGNORECASE, regex=True)) & ~df['Name'].str.contains('Mega', flags=re.IGNORECASE, regex=True)]
# Out:
#        #       Name    Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 20    16     Pidgey    Normal    Flying   40      45       40       35
# 21    17  Pidgeotto    Normal    Flying   63      60       55       50
# 22    18    Pidgeot    Normal    Flying   83      80       75       70
# 30    25    Pikachu  Electric       NaN   35      55       40       50
# 136  127     Pinsir       Bug       NaN   65     125      100       55
# 186  172      Pichu  Electric       NaN   20      40       15       35
# 219  204     Pineco       Bug       NaN   50      65       90       35
# 239  221  Piloswine       Ice    Ground  100     100       80       60
# 438  393     Piplup     Water       NaN   53      51       53       61
# 558  499    Pignite      Fire  Fighting   90      93       55       70
# 578  519     Pidove    Normal    Flying   50      55       50       36
#
#      Sp. Def  Speed  Generation  Legendary
# 20        35     56           1      False
# ...

# %%
df['Type 2'] = df['Type 2'].fillna('')
df.loc[(df['Type 2'].str.contains('Fairy', flags=re.I, regex=True) & df['Legendary'] == True)]
# Out:
#        #                 Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie   Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie   Rock  Fairy  50     160      110      160
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True

# %%
df.loc[df['Total'] > 500, ['Generation']] = '666'
df.loc[df['Total'] > 500]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\top\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.loc[df['Total'] > 500, ['Generation']] = '666'
# ...

# %%
df.groupby('Type 1')['Defense'].mean().sort_values(ascending=False)
# Out:
# Type 1
# Dragon      83.580645
# Normal      76.075269
# Fairy       74.117647
# Psychic     73.803922
# Ground      73.781250
# Ice         72.000000
# Water       71.827273
# Flying      70.750000
# Fire        69.903846
# Fighting    69.851852
# Grass       67.779412
# Poison      67.250000
# Steel       66.833333
# Dark        66.806452
# Rock        66.487805
# Ghost       64.437500
# Hahaue      64.304348
# Electric    59.627907
# Bug         56.884058
# Name: HP, dtype: float64

# %%
df['count'] = 1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       31
# Electric     43
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        68
# Ground       32
# Hahaue       23
# Ice          24
# Normal       93
# Poison       28
# Psychic      51
# Rock         41
# Steel        24
# Water       110
# Name: count, dtype: int64

# %% [markdown]
# ### Working with large amounts of Data

# %%
sample = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('pokemon_data.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()

    sample = pd.concat([sample, results])

print(sample)
# Out:
#          # Name Type 1 Type 2 HP Attack Defense Sp. Atk Sp. Def Speed  \
# Fire     1    1    NaN      0  1      1       1       1       1     1
# Grass    4    4    NaN      4  4      4       4       4       4     4
# Fire     4    4    NaN      3  4      4       4       4       4     4
# Water    1    1    NaN      0  1      1       1       1       1     1
# Bug      2    2    NaN      0  2      2       2       2       2     2
# ...     ..  ...    ...    ... ..    ...     ...     ...     ...   ...
# Fairy    1    1    NaN      0  1      1       1       1       1     1
# Flying   2    2    NaN      2  2      2       2       2       2     2
# Fire     1    1    NaN      1  1      1       1       1       1     1
# Psychic  2    2    NaN      2  2      2       2       2       2     2
# Rock     2    2    NaN      2  2      2       2       2       2     2
#
#         Generation Legendary
# Fire             1         1
# Grass            4         4
# Fire             4         4
# ...
